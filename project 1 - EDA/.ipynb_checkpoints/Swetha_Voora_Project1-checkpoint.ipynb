# %% [markdown]
# ## PROJECT-1
# ## PRESENTED BY - SWETHA VOORA
# ## CS675 - INTRO TO DATA SCIENCE
# ## The aim of this project is to perform Exploratory Data Analysis on the Telecommunication industry's customer churn dataset to understand the issues in the data and find correlation among the various features in order to improve/lower customer churn predictions.

# %% [markdown]
# ## Importing the necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data = pd.read_csv('telco-customer-churn.csv')

# %% [markdown]
# # Understanding the Data - Todo
# - What all columns are provided in the given dataset?
# - What is the shape of the given data? (Number of Rows and Columns)
# - Checking if there are any missing values in any of the columns
#     - If Yes, We need to either remove those rows or replace them with a value
#     * If No, We continue with the next steps
# - Checking the data types of all the columns(Using info or dtypes methods)

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ### There are no null values in the given data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# # Understanding the Data - Conclusion
#
# - We are provided with 7043 rows and 21 columns in the dataset
# - There are no missing values in the given data
# - #### We check the datatype of all the columns and can change the below columns:
#     - SeniorCitizen dtype can be changed from int64 to object, to maintain consistency along with other categorical features
#     - TotalCharges dtype can be changed from object to float64, as this is a Numerical feature

# %% [markdown]
# # Data Cleaning - Todo

# %%
data['SeniorCitizen'] = data['SeniorCitizen'].apply(lambda x: 'Yes' if x==1 else 'No')

# %%
data['SeniorCitizen']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: SeniorCitizen, Length: 7043, dtype: object

# %%
data.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# data['TotalCharges'] = pd.to_numeric(data['TotalCharges'])

# %%
 data.loc[488]
# Out:
# customerID                         4472-LVYGI
# gender                                 Female
# SeniorCitizen                              No
# Partner                                   Yes
# Dependents                                Yes
# tenure                                      0
# PhoneService                               No
# MultipleLines                No phone service
# InternetService                           DSL
# OnlineSecurity                            Yes
# OnlineBackup                               No
# DeviceProtection                          Yes
# TechSupport                               Yes
# StreamingTV                               Yes
# StreamingMovies                            No
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                      No
# ...

# %% [markdown]
# ### Problem:
# - We see that the **TotalCharges** value is empty for the row 488.
# - So, we need to come up with a solution to be able to convert the dtype of TotalCharges from string to float even when its empty.
# - And then remove the rows with null value in the **TotalCharges** column using dropna.
#
# ### Solution:
# - we use pd.to_numeric with the errors='coerce' parameter
#     - This converts values that can be parsed as numbers to float
#     - **replaces non-numeric values with NaN.**
# - This will help us handle null/non-numeric values in the column, when converting from string dtype to float.

# %%
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors = 'coerce')

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen        object
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %% [markdown]
# - We know that the null/non-numeric values in the string format of TotalCharges are replaced with NaN in float.
# - So, We need to remove the rows with NaN values in TotalCharges Column

# %%
data.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
data.loc[data['TotalCharges'].isnull()==True]
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female            No     Yes        Yes       0
# 753   3115-CZMZD    Male            No      No        Yes       0
# 936   5709-LVOEQ  Female            No     Yes        Yes       0
# 1082  4367-NUYAO    Male            No     Yes        Yes       0
# 1340  1371-DWPAZ  Female            No     Yes        Yes       0
# 3331  7644-OMVMY    Male            No     Yes        Yes       0
# 3826  3213-VVOLG    Male            No     Yes        Yes       0
# 4380  2520-SGTTA  Female            No     Yes        Yes       0
# 5218  2923-ARZLG    Male            No     Yes        Yes       0
# 6670  4075-WKNIU  Female            No     Yes        Yes       0
# 6754  2775-SEFEE    Male            No      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.dropna(subset=['TotalCharges'],inplace=True)

# %%
data.shape
# Out:
# (7032, 21)

# %% [markdown]
# ### The CustomerID column doesnt play any role in the Customer Churn. Hence, we will delete it from the dataset.

# %%
data.drop('customerID',axis=1, inplace=True)

# %%
data.shape
# Out:
# (7032, 20)

# %%
data.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            No     Yes         No       1           No
# 1    Male            No      No         No      34          Yes
# 2    Male            No      No         No       2          Yes
# 3    Male            No      No         No      45           No
# 4  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# # Finding Outliers
#
# - Approach 1 : Using Z-score
# - Approach 2 : Using Box-plot

# %% [markdown]
# ## Finding Outliers using z-score

# %%
# Specify the columns for which you want to calculate Z-scores and identify outliers
columns_to_check = ['TotalCharges', 'MonthlyCharges', 'tenure']

# Initialize an empty DataFrame to store outliers
outliers = pd.DataFrame()

# Calculate Z-scores and identify outliers for each column
for column in columns_to_check:
    z_scores = stats.zscore(data[column]) # Calculate the Z-score for the 'values' column
    threshold = 3 # Define a threshold for considering a point as an outlier (e.g., Z-score > 3)
    column_outliers = data[abs(z_scores) > threshold] # Identify outliers based on the threshold
    outliers = pd.concat([outliers,column_outliers])

print("Outliers:")
print(outliers)
# Out:
# Outliers:
# Empty DataFrame
# Columns: [gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []

# %% [markdown]
# ## Finding Outliers using Boxplots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a box plot for all numerical columns in the DataFrame
plt.figure(figsize=(10, 6))  # Set the size of the plot
sns.boxplot(data=data['tenure'], orient='v')  # 'orient' specifies vertical orientation
plt.title("Box Plot of Tenure Column")
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.show()

# Create a box plot for all numerical columns in the DataFrame
plt.figure(figsize=(10, 6))  # Set the size of the plot
sns.boxplot(data=data['MonthlyCharges'], orient='v')  # 'orient' specifies vertical orientation
plt.title("Box Plot of MonthlyCharges Column")
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.show()

# Create a box plot for all numerical columns in the DataFrame
plt.figure(figsize=(10, 6))  # Set the size of the plot
sns.boxplot(data=data['TotalCharges'], orient='v')  # 'orient' specifies vertical orientation
plt.title("Box Plot of TotalCharges Column")
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.show()

# %% [markdown]
# Data points that fall beyond the whiskers are typically considered potential outliers. These are observations that significantly deviate from the majority of the data.
#
# **There are no Outliers as per the above box-plot for the numerical columns**

# %% [markdown]
# # Listing the Features:(**Before Transforming to numeric features**)
#
# - Categorical Features
# - Numerical Features
# - Target Feature

# %%
text_columns = [col for col in data.columns if data[col].dtype == 'object' and col != 'Churn']
number_columns = [col for col in data.columns if data[col].dtype == 'float64' or data[col].dtype=='int64']
print("CATEGORICAL FEATURES: \n", text_columns, "\n")
print("NUMERICAL FEATURES: \n", number_columns,"\n")
print("TARGET FEATURE: ", 'Churn')
# Out:
# CATEGORICAL FEATURES:
#  ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
#
# NUMERICAL FEATURES:
#  ['tenure', 'MonthlyCharges', 'TotalCharges']
#
# TARGET FEATURE:  Churn

# %% [markdown]
# # Transform data – all entries should be numeric.
#
# - One Hot Encoding
# - Using this approach to convert all the categorical features into numeric features

# %%
# Use pandas get_dummies to perform one-hot encoding
# The pd.get_dummies function creates new binary columns for each category in each column, 
# resulting in a DataFrame with numeric features.
data_encoded = pd.get_dummies(data, columns=text_columns)
data_encoded
# Out:
#       tenure  MonthlyCharges  TotalCharges Churn  gender_Female  gender_Male  \
# 0          1           29.85         29.85    No              1            0
# 1         34           56.95       1889.50    No              0            1
# 2          2           53.85        108.15   Yes              0            1
# 3         45           42.30       1840.75    No              0            1
# 4          2           70.70        151.65   Yes              1            0
# ...      ...             ...           ...   ...            ...          ...
# 7038      24           84.80       1990.50    No              0            1
# 7039      72          103.20       7362.90    No              1            0
# 7040      11           29.60        346.45    No              1            0
# 7041       4           74.40        306.60   Yes              0            1
# 7042      66          105.65       6844.50    No              0            1
#
# ...

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 47 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   tenure                                   7032 non-null   int64
#  1   MonthlyCharges                           7032 non-null   float64
#  2   TotalCharges                             7032 non-null   float64
#  3   Churn                                    7032 non-null   object
#  4   gender_Female                            7032 non-null   uint8
#  5   gender_Male                              7032 non-null   uint8
#  6   SeniorCitizen_No                         7032 non-null   uint8
#  7   SeniorCitizen_Yes                        7032 non-null   uint8
#  8   Partner_No                               7032 non-null   uint8
#  9   Partner_Yes                              7032 non-null   uint8
# ...

# %% [markdown]
# # List all types of data:(**After Transformation**)
#
# - Categorical Features
# - Numeric Features
# - Target Feature

# %%
encoded_category_columns = [col for col in data_encoded.columns if data_encoded[col].dtype == 'uint8']
encoded_number_columns = [col for col in data.columns if data[col].dtype == 'float64' or data[col].dtype=='int64']

print("CATEGORICAL FEATURES: \n", encoded_category_columns, "\n")
print("NUMERICAL FEATURES: \n", encoded_number_columns,"\n")
print("TARGET FEATURE: ", 'Churn')
# Out:
# CATEGORICAL FEATURES:
# ...

# %% [markdown]
# # Data Cleaning - Done
#
# From the above dataset we understand that we have 3 types of columns/features:
# - We have transformed the data such that all the features are numerical(using one hot encoding)
# - Categorical Features, Numerical Features, Dependent Feature : CHURN
# - There are no outliers in our numerical data

# %% [markdown]
# # Exploratory Data Analysis - Todo

# %%
# text_columns.apply(col, lambda data[col].value_counts().plot(kind='pie'))
num_columns = len(text_columns)
fig, axes = plt.subplots(1, num_columns, figsize=(num_columns * 6, 6))

for i, col in enumerate(text_columns):
    data[col].value_counts().plot(kind='pie', ax=axes[i], autopct='%1.1f%%')
    axes[i].set_title(col)

plt.show()

# %%
data.groupby(data['Churn']).agg({'Churn':'count'}).plot(kind='barh')
# Out:
# <Axes: ylabel='Churn'>

# %% [markdown]
# # From the above graph, It is evident that the telco company has many loyal customers when compared to the customers who churn.

# %% [markdown]
# ## Need to find correlation between each feature and the target feature

# %%
crosstab = pd.crosstab(data['SeniorCitizen'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of SeniorCitizen vs. Churn")
plt.xlabel("SeniorCitizen")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## -  From the above graph, We can say that seniorcitizens are more loyal to the company

# %%
crosstab = pd.crosstab(data['Partner'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of Partner vs. Churn")
plt.xlabel("Partner")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## The churn rate is more in customers who dont have partners

# %%
crosstab = pd.crosstab(data['gender'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of gender vs. Churn")
plt.xlabel("gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## -  We can understand Gender feature does not play a role in the churn rate as the churn rate of customers is almost same in both genders.

# %%
    
crosstab = pd.crosstab(data['Dependents'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of Dependents vs. Churn")
plt.xlabel("Dependents")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## - Customers with no dependents are churning more, when compared to customers with dependents(Similar to Partner feature)

# %%
    
crosstab = pd.crosstab(data['PhoneService'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of PhoneService vs. Churn")
plt.xlabel("PhoneService")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Customers with no phone-service are staying loyal to the company. This could be because, they have not started using this service provided by the telco company
#  - Further, About 500 customers do not have phone service, and most of them are loyal to the company

# %%
crosstab = pd.crosstab(data['MultipleLines'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of MultipleLines vs. Churn")
plt.xlabel("MultipleLines")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Key Notes:
# - There are about (500 + 200) customers with no phone service
# - Their churn rate is more when companred to the customers with multiple lines. Their churn rate is about 2/7 => 35%
# - Among the customers with multiple lines:
#     - Yes: (2000 + 800) customers
#         - Their churn rate is 8/20 => 40%
#     - No: (2500 + 800) cusomters
#         - Thier churn rate is 8/25 => <40%
#
# - **So, The customers who are not having a phone service are likely planning on getting a new service**
# - **And the customers with phone service have many other factors affecting their decision on whether or not to churn**

# %%
crosstab = pd.crosstab(data['InternetService'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of InternetService vs. Churn")
plt.xlabel("InternetService")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Key Notes:
# - Cutomers with no Internet service are staying loyal to the company
# - Customers with the Fiber Optic Internetservice are churning the most.(That could be due to the high charges of this kind of internet service)
# - Customers with the DSL Internetservice seem to have other factors involved in their decision to churn or not.

# %%
crosstab = pd.crosstab(data['OnlineSecurity'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of OnlineSecurity vs. Churn")
plt.xlabel("OnlineSecurity")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Key Take aways:
# - Customers with no Internet Service are not churning
# - Customers with No Onlinesecuirty are churning the most
# - Customers with Onlinesecurity are churning very less when compared to the customers with no OnlineSecurity

# %%
crosstab = pd.crosstab(data['OnlineBackup'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of OnlineBackup vs. Churn")
plt.xlabel("OnlineBackup")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## We see similar behaviours of customers in the OnlineBackup feature as well.

# %%
    
crosstab = pd.crosstab(data['DeviceProtection'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of DeviceProtection vs. Churn")
plt.xlabel("DeviceProtection")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## We see similar behaviours of customers in the DeviceProtection feature as well.

# %%
crosstab = pd.crosstab(data['TechSupport'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of TechSupport vs. Churn")
plt.xlabel("TechSupport")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## We see similar behaviours of customers in the TechSupport feature as well.

# %%
crosstab = pd.crosstab(data['StreamingTV'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of StreamingTV vs. Churn")
plt.xlabel("StreamingTV")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Customers with no Internet service are not churning much when compared to the customers with internetservice, who must be having different factors affecting their decision to churn

# %%
crosstab = pd.crosstab(data['StreamingMovies'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of StreamingMovies vs. Churn")
plt.xlabel("StreamingMovies")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## We are seeing similar behaviour in the dataset, in terms of StreamingMovies feature

# %%
crosstab = pd.crosstab(data['Contract'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of Contract vs. Churn")
plt.xlabel("Contract")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## **Key Notes: Having a long term contract helps the company to retain its customers**
# - customers on a two year contract are churning the least
# - and customers who have to renew their contract on a monthly basis are churning the most.

# %%
crosstab = pd.crosstab(data['PaperlessBilling'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of PaperlessBilling vs. Churn")
plt.xlabel("PaperlessBilling")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Customers with Paperless billing are churning more when compared to the customers with no paperless billing.

# %%
crosstab = pd.crosstab(data['PaymentMethod'], data['Churn'])
crosstab.plot(kind='bar', stacked=False)
plt.title("Grouped Bar Chart of PaymentMethod vs. Churn")
plt.xlabel("PaymentMethod")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Customers who are facilitated with automatic payment methods are mostly loyal to the company
# - Customers who are paying through Electronic check are churning the most, followed by the customers paying through mailed check

# %% [markdown]
# # IMPORTANT: HOW IS TENURE AFFECTING THE CHURN RATE

# %%
plt.figure(figsize=(15, 6))
sns.countplot(data=data, x=data['tenure'], hue='Churn')
plt.show()

# %% [markdown]
# ## This above graph shows positive correlation betwen tenure and customer satisfaction.

# %%
data.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %% [markdown]
# From the above two cells, It is evident that:
# - As the tenure of the customer increases at the company, the loyalty increases too.
# - The Average tenure of the customers is about 32 months
# - The Average Monthly charges for a customer is 64 usd. but, about 25% are paying more than 89.86 usd(upto 120 usd/month)
# - Similary, The Average total charges for a customer based on their tenure is 2283. But, about 25% customer are paying above 3794.73 usd.

# %%
sns.lmplot(data=data, x='MonthlyCharges', y='TotalCharges', fit_reg=False)

# %% [markdown]
# ## The above plot shows Positive Correlation between Monthly charges and total charges.

# %%
# KDE(Kernel Density Estimation) plot is a way to visualize the distribution of data in a smooth and continuous manner. 
Mth = sns.kdeplot(data.MonthlyCharges[(data["Churn"] == 'No') ],
                color="Red", fill = True)
Mth = sns.kdeplot(data.MonthlyCharges[(data["Churn"] == 'Yes') ],
                ax =Mth, color="Blue", fill= True)
Mth.legend(["No Churn","Churn"],loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('Monthly Charges')
Mth.set_title('Monthly charges by churn')
# Out:
# Text(0.5, 1.0, 'Monthly charges by churn')

# %% [markdown]
# ### Here it is evident that when the monthly charges are raising, the customers churn is raising too.
# ### It implies that the monthlycharges and the customer satisfaction are negatively correlated.

# %%
Tot = sns.kdeplot(data.TotalCharges[(data["Churn"] == 'No') ],
                color="Red", fill = True)
Tot = sns.kdeplot(data.TotalCharges[(data["Churn"] == 'Yes') ],
                ax =Tot, color="Blue", fill= True)
Tot.legend(["No Churn","Churn"],loc='upper right')
Tot.set_ylabel('Density')
Tot.set_xlabel('Total Charges')
Tot.set_title('Total charges by churn')
# Out:
# Text(0.5, 1.0, 'Total charges by churn')

# %% [markdown]
# ### - we observe that the churn rate is higher when the total charges are lower.
# - The customers stayed loyal as their total charges have reached beyond 8000 usd

# %% [markdown]
# # To see the correlation using a heatmap, we need to change all the categorical to numerical using hot encoding/label encoding

# %%
plt.figure(figsize=(25,20))
sns.heatmap(data_encoded.corr(), cmap="Paired")
# Out:
# /var/folders/_f/48yn95r51nn4d4jl8865yj6w0000gn/T/ipykernel_32657/1890464397.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_encoded.corr(), cmap="Paired")
# <Axes: >

# %% [markdown]
# # EDA - CONCLUSION

# %% [markdown]
# - Contract Type – The long term contract customers are more likely not churn. Having a monthly basis contract leads to more churn.
# - No Online security, No Tech Support category are high churners
# - Having Automatic Payment methods, will help reduce the churn rate
# - Senior Citizens are more likely to no churn
# - Having No Phone/Internet service leads to less churn, as this feature is likely to affect churn rate for many other features
# - As the tenure increases, the customer churn rate decreases
# - As the monthly charges or total charges increase, the churn rate is more likely to increase

# %% [markdown]
# # Train_Test_split(80/20 ratio)

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and test sets (80/20 ratio)
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# %% [markdown]
# # SweetViz

# %%
import sweetviz as sv

# %%
my_report = sv.analyze(data)
# Out:
#                                              |      | [  0%]   00:00 -> (? left)

# %%
my_report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
my_report = sv.compare([train_data, "Training Data"], [test_data, "Test Data"], "Churn")
# Out:
#                                              |      | [  0%]   00:00 -> (? left)

# %%
# Save the comparison report as an HTML file
my_report.show_html('comparison_report.html')
# Out:
# Report comparison_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
